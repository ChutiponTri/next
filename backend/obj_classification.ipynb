# %% [markdown]
# ### Housepital Object Classification Model

# %%
import torch
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.transforms import functional as F
import torchvision.transforms as T
from torch.utils.data import DataLoader
from pycocotools.coco import COCO
import os
from PIL import Image, ImageOps

def get_transform():
    return T.Compose([
        T.ToTensor(),
        T.Resize((640, 640)),  # Stretch to 640x640
        T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Standard normalization
    ])

def auto_orient(image):
    # Auto-orient the image based on EXIF data
    try:
        image = Image.open(image)
        image = ImageOps.exif_transpose(image)
    except Exception as e:
        print(f"Error in auto-orienting image: {e}")
    return image

def validate_and_fix_boxes(target):
    boxes = target["boxes"]
    
    # Ensure boxes is 2D with shape [num_boxes, 4]
    if boxes.dim() == 1:
        boxes = boxes.view(-1, 4)  # Reshape to 2D if it's 1D
    
    # Ensure width and height are >= 1
    x_min, y_min, x_max, y_max = boxes[:, 0], boxes[:, 1], boxes[:, 2], boxes[:, 3]
    x_max = torch.max(x_min + 1, x_max)  # Ensure width is >= 1
    y_max = torch.max(y_min + 1, y_max)  # Ensure height is >= 1
    
    # Fix boxes and return them
    target["boxes"] = boxes
    return target


# Define a custom dataset class for COCO
class COCODataset(torch.utils.data.Dataset):
    def __init__(self, img_dir, annotation_file, transforms=None):
        self.img_dir = img_dir
        self.coco = COCO(annotation_file)
        self.transforms = transforms
        self.image_ids = list(self.coco.imgs.keys())

    def __len__(self):
        return len(self.image_ids)

    def __getitem__(self, idx):
        image_id = self.image_ids[idx]
        image_info = self.coco.loadImgs(image_id)[0]
        image_path = os.path.join(self.img_dir, image_info['file_name'])
        
        # Apply Auto-Orientation
        image = auto_orient(image_path)
        
        # Load annotations
        ann_ids = self.coco.getAnnIds(imgIds=image_id)
        annotations = self.coco.loadAnns(ann_ids)
        
        # Prepare targets
        boxes = []
        labels = []
        for ann in annotations:
            bbox = ann['bbox']
            # COCO uses [x, y, width, height], but PyTorch uses [x_min, y_min, x_max, y_max]
            boxes.append([bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1] + bbox[3]])
            labels.append(ann['category_id'])  # Assuming category_id represents bed sore grades (1-4)
        
        boxes = torch.as_tensor(boxes, dtype=torch.float32)
        labels = torch.as_tensor(labels, dtype=torch.int64)
        target = {"boxes": boxes, "labels": labels, "image_id": torch.tensor([image_id])}

        # Apply transforms if provided
        if self.transforms:
            image = self.transforms(image)
        target = validate_and_fix_boxes(target)

        return image, target


# Paths for train, valid, and test directories from both versions
train_dir_v1 = "dataset/pressureV1/train"
train_annotations_v1 = "dataset/pressureV1/train/_annotations.coco.json"
valid_dir_v1 = "dataset/pressureV1/valid"
valid_annotations_v1 = "dataset/pressureV1/valid/_annotations.coco.json"
test_dir_v1 = "dataset/pressureV1/test"
test_annotations_v1 = "dataset/pressureV1/test/_annotations.coco.json"

train_dir_v2 = "dataset/pressureV2/train"
train_annotations_v2 = "dataset/pressureV2/train/_annotations.coco.json"
valid_dir_v2 = "dataset/pressureV2/valid"
valid_annotations_v2 = "dataset/pressureV2/valid/_annotations.coco.json"
test_dir_v2 = "dataset/pressureV2/test"
test_annotations_v2 = "dataset/pressureV2/test/_annotations.coco.json"

# Datasets and loaders
batch_size = 2

# Combine the datasets into single dataset loaders
train_dataset = torch.utils.data.ConcatDataset([
    COCODataset(train_dir_v1, train_annotations_v1, transforms=get_transform()),
    COCODataset(train_dir_v2, train_annotations_v2, transforms=get_transform())
])

valid_dataset = torch.utils.data.ConcatDataset([
    COCODataset(valid_dir_v1, valid_annotations_v1, transforms=get_transform()),
    COCODataset(valid_dir_v2, valid_annotations_v2, transforms=get_transform())
])

test_dataset = torch.utils.data.ConcatDataset([
    COCODataset(test_dir_v1, test_annotations_v1, transforms=get_transform()),
    COCODataset(test_dir_v2, test_annotations_v2, transforms=get_transform())
])

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=lambda x: tuple(zip(*x)))
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=lambda x: tuple(zip(*x)))
# Out:
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!

# %%
import torch
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.faster_rcnn import GeneralizedRCNNTransform

# Number of classes: 1 background + 4 bed sore grades
NUM_CLASSES = 5  # Including the background class

# Pre-trained Faster R-CNN with ResNet50 backbone
def get_faster_rcnn_model():
    # Load pre-trained Faster R-CNN model with a ResNet50 backbone
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
    
    # Get the input features from the pre-trained model's classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    
    # Replace the classifier with a new one that outputs NUM_CLASSES (4 classes + 1 background)
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, NUM_CLASSES)
    
    # Modify the image transform for your custom dataset (e.g., using 640x640 images)
    model.transform = GeneralizedRCNNTransform(min_size=640, max_size=640, image_mean=[0.485, 0.456, 0.406], image_std=[0.229, 0.224, 0.225])
    
    return model


# Set custom directory for model downloads
os.environ["TORCH_HOME"] = "D:/Practice Housepital Back/model/pretrain"

# Create the model
model = get_faster_rcnn_model()

# Move model to the appropriate device (GPU or CPU)
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
model.to(device)
# Out:
# c:\Users\lenovo\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\lenovo\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(640,), max_size=640, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=0.0)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=0.0)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=0.0)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=0.0)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=0.0)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=0.0)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=0.0)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=0.0)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=0.0)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=0.0)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=0.0)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0-3): 4 x Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=5, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=20, bias=True)
#     )
#   )
# )

# %%
import torch
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader
from tqdm import tqdm
import time

# Define the training loop
def train(model, train_loader, valid_loader, num_epochs=10, lr=1e-4, device=None):
    model.to(device)
    
    # Define optimizer (Adam for Faster R-CNN)
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=0.0001)
    
    # Define the learning rate scheduler (optional)
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
    
    # Set model to training mode
    model.train()
    
    # Train the model
    for epoch in range(num_epochs):
        print(f"Epoch {epoch + 1}/{num_epochs}")
        start_time = time.time()
        
        # Training phase
        model.train()
        train_loss = 0
        count = 0
        for images, targets in tqdm(train_loader, desc="Training"):
            images = [image.to(device) for image in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            # Zero gradients
            optimizer.zero_grad()

            # Forward pass
            loss_dict = model(images, targets)
            
            # Sum up the losses
            losses = sum(loss for loss in loss_dict.values())
            
            # Backward pass and optimization
            losses.backward()
            optimizer.step()

            # Track training loss
            train_loss += losses.item()

            # count += 1
            # if count == 2:
            #     break

        # Average training loss
        train_loss /= len(train_loader)
        
        # Validation phase
        valid_loss = 0
        model.eval()  # Set model to evaluation mode
        count = 0
        with torch.no_grad():
            valid_loss = 0
            for images, targets in tqdm(valid_loader, desc="Validating"):
                images = [image.to(device) for image in images]
                targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

                # Forward pass
                loss_dict = model(images, targets)

                # Process losses if it's a dictionary
                try:
                    losses = sum(loss.item() for loss in loss_dict.values())
                    valid_loss += losses
                except:
                    pass

                # count += 1
                # if count == 2:
                #     break

        # Average validation loss
        valid_loss /= len(valid_loader)

        # Print epoch statistics
        print(f"Epoch {epoch + 1} finished in {time.time() - start_time:.2f} seconds")
        print(f"Training Loss: {train_loss:.4f}, Validation Loss: {valid_loss:.4f}")

        # Step the learning rate scheduler
        lr_scheduler.step()

    print("Training complete!")

# Train the model
train(model, train_loader, valid_loader, num_epochs=10, lr=1e-4, device=device)

# %%
import torch
import torch.optim as optim
from torchvision.models.detection import fasterrcnn_resnet50_fpn
from torch.optim.lr_scheduler import StepLR

# Load the model
model = get_faster_rcnn_model()
model.to(device)

# Optimizer
params = [p for p in model.parameters() if p.requires_grad]
# optimizer = optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=0.0001)

# Scheduler
lr_scheduler = StepLR(optimizer, step_size=3, gamma=0.1)

# Training loop with validation
num_epochs = 10
for epoch in range(num_epochs):
    # Training Phase
    model.train()  # Set the model to training mode
    running_loss = 0.0

    for images, targets in train_loader:
        images = [image.to(device) for image in images]
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]
        
        # Zero gradients
        optimizer.zero_grad()
        
        # Forward pass
        loss_dict = model(images, targets)
        
        # Total loss
        losses = sum(loss for loss in loss_dict.values())
        
        # Backward pass
        losses.backward()
        
        # Update weights
        optimizer.step()
        
        # Keep track of the loss
        running_loss += losses.item()
        break
        

    # Print average loss for the epoch
    print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {running_loss/len(train_loader)}")
    
    # Step the learning rate scheduler
    lr_scheduler.step()

    # Save the model after each epoch
    # torch.save(model.state_dict(), f"fasterrcnn_epoch_{epoch+1}.pth")

    # Validation Phase
    model.eval()  # Set the model to evaluation mode
    with torch.no_grad():  # No gradients needed for inference
        validation_loss = 0.0
        for images, targets in valid_loader:
            images = [image.to(device) for image in images]
            targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

            # Forward pass
            loss_dict = model(images, targets)
            
            # Total loss for validation
            try:
                losses = sum(loss for loss in loss_dict.values())
                validation_loss += losses.item()
            except:
                pass

            break

        # Print validation loss
        print(f"Epoch [{epoch+1}/{num_epochs}], Validation Loss: {validation_loss/len(valid_loader)}")
    break

    # Optionally, print the validation performance (e.g., mAP or IoU)
# Out:
# Epoch [1/10], Training Loss: 0.0006994074583053589
# Epoch [1/10], Validation Loss: 0.0

# %%
# Save the model

torch.save(model.state_dict(), "model/v2.pth")
print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
# Load the model

# Create the model
model = get_faster_rcnn_model()

# Move model to the appropriate device (GPU or CPU)
model.load_state_dict(torch.load("model/latest_model.pth"))
model.to("cpu")
print("Model Loaded Successfully")
# Out:
# c:\Users\lenovo\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\lenovo\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_11744\3920789089.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("model/latest_model.pth"))
# Model Loaded Successfully

# %%
import torch
from tqdm import tqdm
import numpy as np
import torch


def coco_to_xyxy(box):
    """Convert COCO bbox format [x, y, w, h] to [x_min, y_min, x_max, y_max]."""
    x_min, y_min, width, height = box
    x_max = x_min + width
    y_max = y_min + height
    return [x_min, y_min, x_max, y_max]

def calculate_iou(box1, box2):
    """Calculate Intersection over Union (IoU) for two boxes in [x_min, y_min, x_max, y_max] format."""
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    intersection = max(0, x2 - x1) * max(0, y2 - y1)
    
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union = box1_area + box2_area - intersection
    
    return intersection / union if union > 0 else 0

def test_model_acc(model, test_loader, device, iou_threshold=0.5):
    """Evaluate model accuracy with a focus on category ID and IoU alignment."""
    model.to(device)
    model.eval()
    
    correct_detections = 0  # Both IoU and category match
    correct_categories = 0  # Category match regardless of IoU
    total_targets = 0       # Total ground truth objects
    total_predictions = 0   # Total predicted objects
    
    with torch.no_grad():
        for images, targets in tqdm(test_loader, desc="Testing"):
            images = [img.to(device) for img in images]
            outputs = model(images)
            
            for i, output in enumerate(outputs):
                pred_boxes = output["boxes"].cpu().numpy()
                pred_labels = output["labels"].cpu().numpy()
                pred_scores = output["scores"].cpu().numpy()
                
                # Convert true boxes to [x_min, y_min, x_max, y_max]
                true_boxes = np.array([coco_to_xyxy(box) for box in targets[i]["boxes"].cpu().numpy()])
                true_labels = targets[i]["labels"].cpu().numpy()
                
                total_targets += len(true_boxes)
                total_predictions += len(pred_boxes)
                
                # Match true boxes with predictions
                for true_box, true_label in zip(true_boxes, true_labels):
                    match_found = False
                    category_correct = False
                    for pred_box, pred_label, pred_score in zip(pred_boxes, pred_labels, pred_scores):
                        iou = calculate_iou(true_box, pred_box)
                        if pred_label == true_label:
                            category_correct = True
                        if iou >= iou_threshold and pred_label == true_label:
                            correct_detections += 1
                            match_found = True
                            break
                    
                    if category_correct:
                        correct_categories += 1  # Category is correct even if IoU is low
                    
                    if not match_found:
                        pass  # No IoU and category match for this true object
    
    # Metrics
    precision = correct_detections / total_predictions if total_predictions > 0 else 0
    recall = correct_detections / total_targets if total_targets > 0 else 0
    classification_accuracy = correct_categories / total_targets if total_targets > 0 else 0
    iou_accuracy = correct_detections / total_targets if total_targets > 0 else 0
    
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}")
    print(f"Classification Accuracy: {classification_accuracy:.4f}, IoU Accuracy: {iou_accuracy:.4f}")
    
    return precision, recall, classification_accuracy, iou_accuracy


test_model_acc(model, test_loader, device)
# Out:
# Testing:   0%|          | 0/206 [00:00<?, ?it/s]
# Testing: 100%|██████████| 206/206 [00:57<00:00,  3.59it/s]
# Precision: 0.4471, Recall: 0.9854
# Classification Accuracy: 0.9854, IoU Accuracy: 0.9854
# (0.44713656387665196,
#  0.9854368932038835,
#  0.9854368932038835,
#  0.9854368932038835)

# %%
from tqdm import tqdm

def test_model(model, test_loader, device=None):
    model.to(device)
    model.eval()  # Set the model to evaluation mode
    
    predictions = []
    with torch.no_grad():
        for images, targets in tqdm(test_loader, desc="Testing"):
            # Move images to the device
            images = [image.to(device) for image in images]
            
            # Get predictions from the model
            outputs = model(images)
            
            # Process outputs
            for i, output in enumerate(outputs):
                pred_boxes = output['boxes'].cpu().numpy()
                pred_labels = output['labels'].cpu().numpy()
                pred_scores = output['scores'].cpu().numpy()
                
                # Optionally compare with ground truth targets
                true_boxes = targets[i]['boxes'].cpu().numpy()
                true_labels = targets[i]['labels'].cpu().numpy()
                
                # Store predictions and ground truth
                predictions.append({
                    "image_id": targets[i]["image_id"].item(),
                    "pred_boxes": pred_boxes,
                    "pred_labels": pred_labels,
                    "pred_scores": pred_scores,
                    "true_boxes": true_boxes,
                    "true_labels": true_labels
                })
    
    return predictions


test_model(model, test_loader, device)

# %%
import json

train_annotations_v1 = "dataset/pressureV1/train/_annotations.coco.json"
with open(train_annotations_v1, "r") as file:
    data = json.load(file)

print(data.keys())
print(data["categories"])
for val in data.keys():
    if val != "categories":
        try:
            print(val, "=", data[val][0])
        except:
            pass
# Out:
# dict_keys(['info', 'licenses', 'categories', 'images', 'annotations'])
# [{'id': 0, 'name': 'stage1-stage2-stage3-stage4', 'supercategory': 'none'}, {'id': 1, 'name': 'stage1', 'supercategory': 'stage1-stage2-stage3-stage4'}, {'id': 2, 'name': 'stage2', 'supercategory': 'stage1-stage2-stage3-stage4'}, {'id': 3, 'name': 'stage3', 'supercategory': 'stage1-stage2-stage3-stage4'}, {'id': 4, 'name': 'stage4', 'supercategory': 'stage1-stage2-stage3-stage4'}]
# licenses = {'id': 1, 'url': 'https://creativecommons.org/licenses/by/4.0/', 'name': 'CC BY 4.0'}
# images = {'id': 0, 'license': 1, 'file_name': 'undermining0003_jpg.rf.025bab6b80a9c1c801fcba72a2332fb1.jpg', 'height': 640, 'width': 640, 'date_captured': '2024-12-15T07:55:13+00:00'}
# annotations = {'id': 0, 'image_id': 0, 'category_id': 3, 'bbox': [3, 3, 637, 637], 'area': 405769, 'segmentation': [], 'iscrowd': 0}

# %%
import json

test_annotations_v1 = "dataset/pressureV1/test/_annotations.coco.json"
with open(test_annotations_v1, "r") as file:
    data = json.load(file)

print(data.keys())
print(data["categories"])
for val in data.keys():
    if val != "categories":
        try:
            print(val, "=", data[val][0])
        except:
            pass
# Out:
# dict_keys(['info', 'licenses', 'categories', 'images', 'annotations'])
# [{'id': 0, 'name': 'stage1-stage2-stage3-stage4', 'supercategory': 'none'}, {'id': 1, 'name': 'stage1', 'supercategory': 'stage1-stage2-stage3-stage4'}, {'id': 2, 'name': 'stage2', 'supercategory': 'stage1-stage2-stage3-stage4'}, {'id': 3, 'name': 'stage3', 'supercategory': 'stage1-stage2-stage3-stage4'}, {'id': 4, 'name': 'stage4', 'supercategory': 'stage1-stage2-stage3-stage4'}]
# licenses = {'id': 1, 'url': 'https://creativecommons.org/licenses/by/4.0/', 'name': 'CC BY 4.0'}
# images = {'id': 0, 'license': 1, 'file_name': 'undermining0003_jpg.rf.025bab6b80a9c1c801fcba72a2332fb1.jpg', 'height': 640, 'width': 640, 'date_captured': '2024-12-15T07:55:13+00:00'}
# annotations = {'id': 0, 'image_id': 0, 'category_id': 3, 'bbox': [3, 3, 637, 637], 'area': 405769, 'segmentation': [], 'iscrowd': 0}

# %%
from sklearn.metrics import classification_report
from tqdm import tqdm
import numpy as np

def coco_to_xyxy(box):
    """Convert COCO bbox format [x, y, w, h] to [x_min, y_min, x_max, y_max]."""
    x_min, y_min, width, height = box
    x_max = x_min + width
    y_max = y_min + height
    return [x_min, y_min, x_max, y_max]

def calculate_iou(box1, box2):
    """Calculate Intersection over Union (IoU) for two boxes in [x_min, y_min, x_max, y_max] format."""
    x1 = max(box1[0], box2[0])
    y1 = max(box1[1], box2[1])
    x2 = min(box1[2], box2[2])
    y2 = min(box1[3], box2[3])
    intersection = max(0, x2 - x1) * max(0, y2 - y1)
    
    box1_area = (box1[2] - box1[0]) * (box1[3] - box1[1])
    box2_area = (box2[2] - box2[0]) * (box2[3] - box2[1])
    union = box1_area + box2_area - intersection
    
    return intersection / union if union > 0 else 0

def test_model_acc(model, test_loader, device, iou_threshold=0.5):
    """Evaluate model accuracy and generate classification report."""
    model.to(device)
    model.eval()
    
    true_labels_all = []
    pred_labels_all = []
    
    correct_detections = 0  # Both IoU and category match
    total_targets = 0       # Total ground truth objects
    total_predictions = 0   # Total predicted objects
    
    with torch.no_grad():
        for images, targets in tqdm(test_loader, desc="Testing"):
            images = [img.to(device) for img in images]
            outputs = model(images)
            
            for i, output in enumerate(outputs):
                pred_boxes = output["boxes"].cpu().numpy()
                pred_labels = output["labels"].cpu().numpy()
                pred_scores = output["scores"].cpu().numpy()
                
                # Convert true boxes to [x_min, y_min, x_max, y_max]
                true_boxes = np.array([coco_to_xyxy(box) for box in targets[i]["boxes"].cpu().numpy()])
                true_labels = targets[i]["labels"].cpu().numpy()
                
                total_targets += len(true_boxes)
                total_predictions += len(pred_boxes)
                
                # Collect true and predicted labels
                for true_box, true_label in zip(true_boxes, true_labels):
                    match_found = False
                    for pred_box, pred_label, pred_score in zip(pred_boxes, pred_labels, pred_scores):
                        iou = calculate_iou(true_box, pred_box)
                        if iou >= iou_threshold:
                            pred_labels_all.append(pred_label)
                            true_labels_all.append(true_label)
                            if pred_label == true_label:
                                correct_detections += 1
                            match_found = True
                            break
                    
                    if not match_found:
                        true_labels_all.append(true_label)
                        pred_labels_all.append(-1)  # Indicate no prediction

    # Metrics
    precision = correct_detections / total_predictions if total_predictions > 0 else 0
    recall = correct_detections / total_targets if total_targets > 0 else 0
    
    # Generate classification report
    report = classification_report(true_labels_all, pred_labels_all, zero_division=0)
    print(report)
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}")
    
    return precision, recall, report

test_model_acc(model, test_loader, device)
# Out:
# Testing:   0%|          | 0/206 [00:00<?, ?it/s]
# Testing: 100%|██████████| 206/206 [00:58<00:00,  3.49it/s]
#               precision    recall  f1-score   support
#
#            1       0.95      0.84      0.89        90
#            2       0.72      0.75      0.74       122
#            3       0.60      0.55      0.57       110
#            4       0.75      0.87      0.80        90
#
#     accuracy                           0.74       412
#    macro avg       0.75      0.75      0.75       412
# weighted avg       0.74      0.74      0.74       412
#
# Precision: 0.3370, Recall: 0.7427
# (0.3370044052863436,
#  0.7427184466019418,
#  '              precision    recall  f1-score   support\n\n           1       0.95      0.84      0.89        90\n           2       0.72      0.75      0.74       122\n           3       0.60      0.55      0.57       110\n           4       0.75      0.87      0.80        90\n\n    accuracy                           0.74       412\n   macro avg       0.75      0.75      0.75       412\nweighted avg       0.74      0.74      0.74       412\n')

# %%
from tqdm import tqdm

def test_model(model, test_loader, device=None):
    model.to(device)
    model.eval()  # Set the model to evaluation mode
    
    predictions = []
    with torch.no_grad():
        for images, targets in tqdm(test_loader, desc="Testing"):
            # Move images to the device
            images = [image.to(device) for image in images]
            
            # Get predictions from the model
            outputs = model(images)
            
            # Process outputs
            for i, output in enumerate(outputs):
                pred_boxes = output['boxes'].cpu().numpy()
                pred_labels = output['labels'].cpu().numpy()
                pred_scores = output['scores'].cpu().numpy()
                
                # Optionally compare with ground truth targets
                true_boxes = targets[i]['boxes'].cpu().numpy()
                true_labels = targets[i]['labels'].cpu().numpy()
                
                # Store predictions and ground truth
                predictions.append({
                    "image_id": targets[i]["image_id"].item(),
                    "pred_boxes": pred_boxes,
                    "pred_labels": pred_labels,
                    "pred_scores": pred_scores,
                    "true_boxes": true_boxes,
                    "true_labels": true_labels
                })
    
    return predictions


test_model(model, test_loader, "cpu")
# Out:
# Testing: 100%|██████████| 206/206 [01:54<00:00,  1.79it/s]
# [{'image_id': 0,
#   'pred_boxes': array([[4.8718872e+00, 4.2875061e+00, 6.4000000e+02, 6.3991846e+02],
#          [6.4107361e+00, 1.3876343e-01, 6.4000000e+02, 6.3850623e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2], dtype=int64),
#   'pred_scores': array([0.85856915, 0.34615943], dtype=float32),
#   'true_boxes': array([[  3.,   3., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 1,
#   'pred_boxes': array([[3.8528442e-01, 0.0000000e+00, 6.4000000e+02, 6.3902246e+02],
#          [1.1218262e-01, 6.0907288e+00, 6.4000000e+02, 6.3937598e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.86041284, 0.3759606 ], dtype=float32),
#   'true_boxes': array([[  5.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 2,
#   'pred_boxes': array([[  1.3620911,   1.6354065, 639.78467  , 638.0299   ],
#          [  4.9110107,   2.1372986, 638.3259   , 639.21204  ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.8414373 , 0.41070443], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 3,
#   'pred_boxes': array([[2.6444702e+00, 6.1761475e-01, 6.4000000e+02, 6.3907147e+02],
#          [1.7117310e-01, 2.3329163e+00, 6.3777185e+02, 6.3776538e+02],
#          [2.7982788e+00, 9.1207886e-01, 6.3807861e+02, 6.3908069e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.8603965 , 0.31446484, 0.0809458 ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 4,
#   'pred_boxes': array([[0.0000000e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [6.3146973e-01, 3.7273865e+00, 6.4000000e+02, 6.3560461e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.9520282 , 0.09025844], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 5,
#   'pred_boxes': array([[3.2214355e-01, 3.1868286e+00, 6.4000000e+02, 6.3919318e+02],
#          [5.6381226e-01, 1.4346924e+00, 6.3716724e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.8991502 , 0.66139376], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 6,
#   'pred_boxes': array([[  0.74957275,   1.2944946 , 638.13824   , 638.39734   ],
#          [  0.86209106,   0.69525146, 639.7295    , 639.2283    ]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.97952753, 0.30941036], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 7,
#   'pred_boxes': array([[0.0000000e+00, 2.7960205e-01, 6.4000000e+02, 6.4000000e+02],
#          [2.8495789e+00, 0.0000000e+00, 6.4000000e+02, 6.3960687e+02],
#          [8.3679199e-01, 3.1179810e+00, 6.3827197e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.882992  , 0.580566  , 0.12334942], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 8,
#   'pred_boxes': array([[2.2471008e+00, 5.9643555e-01, 6.4000000e+02, 6.4000000e+02],
#          [3.9926147e-01, 1.9125366e-01, 6.3964868e+02, 6.4000000e+02],
#          [1.5550842e+00, 1.6576233e+00, 6.3945581e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.9013087 , 0.43932393, 0.07401647], dtype=float32),
#   'true_boxes': array([[  7.,   2., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 9,
#   'pred_boxes': array([[3.5107422e-01, 9.0942383e-01, 6.4000000e+02, 6.3932532e+02],
#          [0.0000000e+00, 9.5391846e-01, 6.3632739e+02, 6.3932404e+02],
#          [0.0000000e+00, 1.2294006e+00, 6.3691809e+02, 6.3994702e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.87882197, 0.27841547, 0.18296953], dtype=float32),
#   'true_boxes': array([[  0.,   2., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 10,
#   'pred_boxes': array([[  1.40094  ,   3.4458618, 640.       , 636.81323  ]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.99644667], dtype=float32),
#   'true_boxes': array([[  3.,   5., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 11,
#   'pred_boxes': array([[  2.9896545,   2.205597 , 640.       , 640.       ],
#          [  1.214386 ,   3.05484  , 637.11194  , 640.       ],
#          [  0.       ,   1.427002 , 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.91629744, 0.22142449, 0.05477086], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 12,
#   'pred_boxes': array([[  1.600769 ,   0.       , 639.6843   , 640.       ],
#          [  0.       ,   0.9136963, 640.       , 640.       ],
#          [  0.       ,   1.8206482, 637.0654   , 639.6676   ]],
#         dtype=float32),
#   'pred_labels': array([3, 4, 2], dtype=int64),
#   'pred_scores': array([0.7330703 , 0.41081998, 0.09929998], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 13,
#   'pred_boxes': array([[2.1590576e+00, 2.8607178e-01, 6.4000000e+02, 6.4000000e+02],
#          [0.0000000e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [1.4059143e+00, 3.0653381e+00, 6.3925256e+02, 6.3813135e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 4, 2], dtype=int64),
#   'pred_scores': array([0.9225204 , 0.16527481, 0.10655174], dtype=float32),
#   'true_boxes': array([[  0. ,   1. , 640. , 639.5]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 14,
#   'pred_boxes': array([[  0.        ,   1.8518372 , 636.95276   , 639.3762    ],
#          [  1.0970459 ,   0.80532837, 640.        , 639.73645   ]],
#         dtype=float32),
#   'pred_labels': array([3, 4], dtype=int64),
#   'pred_scores': array([0.6829932, 0.6304964], dtype=float32),
#   'true_boxes': array([[  0. ,   3. , 640. , 639.5]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 15,
#   'pred_boxes': array([[1.8229065e+00, 1.7400208e+00, 6.3984778e+02, 6.4000000e+02],
#          [3.9065552e-01, 7.3522949e-01, 6.3984680e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.82344985, 0.70061666], dtype=float32),
#   'true_boxes': array([[  1.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 16,
#   'pred_boxes': array([[  0.       ,   1.9576111, 640.       , 640.       ],
#          [  0.       ,   0.       , 639.5853   , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.6851204, 0.5771932], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 17,
#   'pred_boxes': array([[  0.     ,   0.     , 640.     , 635.12964]], dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9950105], dtype=float32),
#   'true_boxes': array([[  2. ,   0. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 18,
#   'pred_boxes': array([[  0.       ,   0.       , 638.90295  , 640.       ],
#          [  1.5254211,   4.124237 , 637.30164  , 638.5426   ]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.9008758 , 0.32755017], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 19,
#   'pred_boxes': array([[0.0000000e+00, 4.4389954e+00, 6.3953137e+02, 6.3937561e+02],
#          [2.9053040e+00, 1.5802002e-01, 6.3906995e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.94046485, 0.23683222], dtype=float32),
#   'true_boxes': array([[  1.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 20,
#   'pred_boxes': array([[  5.471649  ,   0.82525635, 639.8213    , 638.59766   ]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9991691], dtype=float32),
#   'true_boxes': array([[  1. ,   0. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 21,
#   'pred_boxes': array([[1.3875732e+00, 1.0128784e+00, 6.4000000e+02, 6.3950952e+02],
#          [3.0794983e+00, 1.2744141e-01, 6.3970349e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.9391373 , 0.10158271], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 22,
#   'pred_boxes': array([[  2.1481628,   4.2875366, 640.       , 638.8551   ],
#          [  3.2215881,   3.3540344, 637.7146   , 638.30896  ],
#          [  0.6623535,   3.52536  , 635.69165  , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([1, 2, 3], dtype=int64),
#   'pred_scores': array([0.73664594, 0.48200658, 0.05093202], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 23,
#   'pred_boxes': array([[  0.       ,   0.       , 638.0414   , 640.       ],
#          [  0.       ,   0.7760925, 639.23303  , 640.       ],
#          [  1.138916 ,   0.       , 638.9708   , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([2, 3, 1], dtype=int64),
#   'pred_scores': array([0.83543193, 0.42627132, 0.34665573], dtype=float32),
#   'true_boxes': array([[  5.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 24,
#   'pred_boxes': array([[0.000000e+00, 5.970764e-01, 6.400000e+02, 6.400000e+02],
#          [0.000000e+00, 0.000000e+00, 6.400000e+02, 6.400000e+02],
#          [0.000000e+00, 0.000000e+00, 6.400000e+02, 6.393128e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.86110175, 0.24331164, 0.13163497], dtype=float32),
#   'true_boxes': array([[  2.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 25,
#   'pred_boxes': array([[  0.       ,   2.3916016, 638.9236   , 640.       ],
#          [  1.3706055,   2.9068298, 640.       , 633.339    ],
#          [  2.9880066,   2.6145325, 639.5608   , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([2, 3, 1], dtype=int64),
#   'pred_scores': array([0.9447217 , 0.08586072, 0.05677078], dtype=float32),
#   'true_boxes': array([[  0.,  15., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 26,
#   'pred_boxes': array([[  0.       ,   1.6064148, 639.5768   , 637.8225   ],
#          [  4.0889587,   0.       , 640.       , 640.       ],
#          [  0.       ,   3.1667175, 639.6387   , 638.0801   ]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.85164267, 0.37746084, 0.11257411], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 27,
#   'pred_boxes': array([[  1.7217102,   0.       , 639.1953   , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9995042], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 28,
#   'pred_boxes': array([[  0.       ,   0.6416321, 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9935681], dtype=float32),
#   'true_boxes': array([[  3.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 29,
#   'pred_boxes': array([[0.0000000e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [1.9297791e+00, 5.0961304e-01, 6.3909509e+02, 6.3988599e+02]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.9764605 , 0.08644205], dtype=float32),
#   'true_boxes': array([[  1. ,   2. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 30,
#   'pred_boxes': array([[1.8558960e+00, 2.3649292e+00, 6.3885590e+02, 6.3807782e+02],
#          [4.7061157e-01, 7.7490234e-01, 6.3826660e+02, 6.3905463e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2], dtype=int64),
#   'pred_scores': array([0.78625804, 0.32541397], dtype=float32),
#   'true_boxes': array([[  0. ,   3. , 640. , 639.5]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 31,
#   'pred_boxes': array([[  0.       ,   0.       , 638.103    , 640.       ],
#          [  0.       ,   0.9439087, 640.       , 639.1377   ],
#          [  1.8780212,   1.2722473, 638.45337  , 637.2435   ]],
#         dtype=float32),
#   'pred_labels': array([2, 3, 1], dtype=int64),
#   'pred_scores': array([0.85704553, 0.35943428, 0.1236963 ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 32,
#   'pred_boxes': array([[  1.4694519,   0.       , 640.       , 640.       ],
#          [  0.       ,   2.041626 , 640.       , 639.904    ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.8907124, 0.2089338], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 33,
#   'pred_boxes': array([[1.5396118e-01, 4.8080444e-01, 6.4000000e+02, 6.4000000e+02],
#          [2.2033691e-01, 0.0000000e+00, 6.3863464e+02, 6.3948352e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.9175787 , 0.18872254], dtype=float32),
#   'true_boxes': array([[  0.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 34,
#   'pred_boxes': array([[  1.3984375,   0.       , 639.05206  , 640.       ],
#          [  0.       ,   1.4946594, 638.42224  , 638.98267  ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.84943515, 0.3328274 ], dtype=float32),
#   'true_boxes': array([[  0.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 35,
#   'pred_boxes': array([[5.3607178e-01, 3.7579956e+00, 6.4000000e+02, 6.3814087e+02],
#          [4.7201233e+00, 6.0211182e-02, 6.3912549e+02, 6.3816089e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.92624444, 0.14312223], dtype=float32),
#   'true_boxes': array([[  8.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 36,
#   'pred_boxes': array([[0.0000000e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [2.4822998e-01, 9.8577881e-01, 6.3653613e+02, 6.3896722e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.68746793, 0.60267884], dtype=float32),
#   'true_boxes': array([[  0.,   3., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 37,
#   'pred_boxes': array([[  0.69885254,   1.4245605 , 640.        , 640.        ],
#          [  3.5315552 ,   3.195984  , 640.        , 638.222     ]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.8973759 , 0.27548692], dtype=float32),
#   'true_boxes': array([[ 10.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 38,
#   'pred_boxes': array([[1.2366333e+00, 2.0842590e+00, 6.4000000e+02, 6.3934717e+02],
#          [1.3247375e+00, 6.6598511e-01, 6.4000000e+02, 6.4000000e+02],
#          [3.0410767e-01, 2.5213623e+00, 6.4000000e+02, 6.3903809e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.8107923 , 0.2259977 , 0.21355107], dtype=float32),
#   'true_boxes': array([[  0. ,   5. , 640. , 639.5]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 39,
#   'pred_boxes': array([[4.3170166e-01, 1.1560364e+00, 6.3879669e+02, 6.3798425e+02],
#          [0.0000000e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.8483185 , 0.45060477], dtype=float32),
#   'true_boxes': array([[  0.,   3., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 40,
#   'pred_boxes': array([[8.1228638e-01, 4.3630981e-01, 6.3663501e+02, 6.3968762e+02],
#          [0.0000000e+00, 0.0000000e+00, 6.3637866e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 4], dtype=int64),
#   'pred_scores': array([0.67723596, 0.6096858 ], dtype=float32),
#   'true_boxes': array([[  0. ,   1. , 640. , 639.5]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 41,
#   'pred_boxes': array([[1.9970703e-01, 1.5393982e+00, 6.4000000e+02, 6.3766113e+02],
#          [0.0000000e+00, 0.0000000e+00, 6.3959015e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.94791865, 0.17369176], dtype=float32),
#   'true_boxes': array([[  0.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 42,
#   'pred_boxes': array([[3.4640503e-01, 9.1705322e-02, 6.3991211e+02, 6.4000000e+02],
#          [1.2359619e+00, 1.4856567e+00, 6.3660608e+02, 6.4000000e+02],
#          [0.0000000e+00, 0.0000000e+00, 6.3943042e+02, 6.3990405e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 4, 2], dtype=int64),
#   'pred_scores': array([0.82377523, 0.45897305, 0.23533703], dtype=float32),
#   'true_boxes': array([[  2. ,   0. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 43,
#   'pred_boxes': array([[2.0169067e-01, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [7.4032593e-01, 2.9993591e+00, 6.3843445e+02, 6.4000000e+02],
#          [3.3412170e+00, 1.5783691e+00, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3, 1], dtype=int64),
#   'pred_scores': array([0.8386493 , 0.21032657, 0.11338413], dtype=float32),
#   'true_boxes': array([[  5.,   4., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 44,
#   'pred_boxes': array([[  0.       ,   0.       , 640.       , 640.       ],
#          [  0.       ,   0.       , 639.90686  , 640.       ],
#          [  2.5075378,   3.9152527, 638.2123   , 635.1416   ]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.7992888 , 0.77194226, 0.07144807], dtype=float32),
#   'true_boxes': array([[  0.,   2., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 45,
#   'pred_boxes': array([[  0.8914795,   0.8852539, 640.       , 637.51434  ],
#          [  2.6275024,   0.       , 640.       , 638.4541   ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.9560637, 0.1499374], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 46,
#   'pred_boxes': array([[0.0000000e+00, 4.6572876e-01, 6.3740637e+02, 6.3827515e+02],
#          [1.1328125e+00, 1.0939941e+00, 6.4000000e+02, 6.4000000e+02],
#          [0.0000000e+00, 9.3780518e-02, 6.3794708e+02, 6.3901343e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 4, 2], dtype=int64),
#   'pred_scores': array([0.8048255 , 0.31248274, 0.09695715], dtype=float32),
#   'true_boxes': array([[  1. ,   0. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 47,
#   'pred_boxes': array([[  1.3287048,   7.7454834, 633.1605   , 640.       ],
#          [  0.       ,   1.4475403, 640.       , 633.8036   ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.96254724, 0.24460213], dtype=float32),
#   'true_boxes': array([[  1.,   2., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 48,
#   'pred_boxes': array([[2.2329712e-01, 1.2239990e+00, 6.3996887e+02, 6.3968689e+02],
#          [3.3981628e+00, 1.4536743e+00, 6.3938831e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 1], dtype=int64),
#   'pred_scores': array([0.85193413, 0.61294836], dtype=float32),
#   'true_boxes': array([[  0. ,   3. , 640. , 639.5]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 49,
#   'pred_boxes': array([[0.0000000e+00, 3.8366699e-01, 6.4000000e+02, 6.4000000e+02],
#          [0.0000000e+00, 1.6232300e+00, 6.4000000e+02, 6.3832196e+02],
#          [3.4141235e+00, 0.0000000e+00, 6.3944647e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.7667769, 0.3751728, 0.3186056], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 50,
#   'pred_boxes': array([[  2.4360352,   2.614441 , 639.76544  , 640.       ],
#          [  0.7241821,   3.7442627, 638.06006  , 640.       ],
#          [  0.       ,   5.311615 , 640.       , 638.85095  ]],
#         dtype=float32),
#   'pred_labels': array([3, 4, 2], dtype=int64),
#   'pred_scores': array([0.8252752 , 0.4771457 , 0.06927895], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 51,
#   'pred_boxes': array([[  0.       ,   0.       , 640.       , 640.       ],
#          [  0.       ,   2.5009155, 640.       , 640.       ],
#          [  0.7029114,   2.679779 , 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([2, 3, 1], dtype=int64),
#   'pred_scores': array([0.89419776, 0.1009419 , 0.08387841], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 52,
#   'pred_boxes': array([[  1.2081299,   1.1480713, 638.8913   , 638.6646   ]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9981255], dtype=float32),
#   'true_boxes': array([[  7.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 53,
#   'pred_boxes': array([[  1.4186401,   2.2872314, 637.13745  , 640.       ],
#          [  0.       ,   0.9237976, 639.88477  , 639.61536  ]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.85215425, 0.47005406], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 54,
#   'pred_boxes': array([[  3.3629456,   0.       , 640.       , 640.       ],
#          [  3.8704224,   3.8321228, 637.9702   , 639.7208   ]],
#         dtype=float32),
#   'pred_labels': array([3, 2], dtype=int64),
#   'pred_scores': array([0.9027373 , 0.32113096], dtype=float32),
#   'true_boxes': array([[  0.,   5., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 55,
#   'pred_boxes': array([[  0.       ,   0.       , 640.       , 640.       ],
#          [  3.7752075,   3.8512878, 638.2935   , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([3, 4], dtype=int64),
#   'pred_scores': array([0.89719766, 0.36033145], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 56,
#   'pred_boxes': array([[  0.95401 ,   0.686676, 638.71375 , 640.      ]], dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9980432], dtype=float32),
#   'true_boxes': array([[  0.,   3., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 57,
#   'pred_boxes': array([[  1.0262146,   0.       , 640.       , 640.       ],
#          [  0.       ,   2.1265564, 639.10986  , 636.5729   ]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.9905539 , 0.15353245], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 58,
#   'pred_boxes': array([[3.7039185e-01, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [5.0393677e-01, 1.6355286e+00, 6.4000000e+02, 6.4000000e+02],
#          [8.4188843e-01, 1.0547180e+00, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3, 1], dtype=int64),
#   'pred_scores': array([0.89724237, 0.18190007, 0.14998816], dtype=float32),
#   'true_boxes': array([[  0.,   2., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 59,
#   'pred_boxes': array([[  2.8222046,   1.7555542, 640.       , 639.392    ],
#          [  1.1992188,   0.       , 637.47955  , 638.7986   ],
#          [  1.903595 ,   3.1087646, 637.47437  , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([1, 2, 3], dtype=int64),
#   'pred_scores': array([0.97497934, 0.4727696 , 0.26076436], dtype=float32),
#   'true_boxes': array([[  1.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 60,
#   'pred_boxes': array([[  0.95617676,   0.        , 640.        , 640.        ],
#          [  5.006775  ,   1.0992126 , 640.        , 640.        ]],
#         dtype=float32),
#   'pred_labels': array([2, 1], dtype=int64),
#   'pred_scores': array([0.9426441 , 0.14505936], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 61,
#   'pred_boxes': array([[6.199951e-01, 2.764557e+00, 6.400000e+02, 6.377500e+02],
#          [0.000000e+00, 9.354980e+00, 6.362282e+02, 6.400000e+02]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.9947043 , 0.06061034], dtype=float32),
#   'true_boxes': array([[  0.,   2., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 62,
#   'pred_boxes': array([[  2.9911804,   1.4358215, 639.2865   , 639.3988   ],
#          [  0.       ,   1.140625 , 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.92528665, 0.32949045], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 63,
#   'pred_boxes': array([[  0.       ,   0.       , 638.11755  , 640.       ],
#          [  3.4257812,   0.930603 , 639.63257  , 637.51904  ]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.7946952, 0.3801792], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 64,
#   'pred_boxes': array([[  3.3912048,   4.9412537, 638.5879   , 639.3572   ],
#          [  1.247406 ,   1.4686584, 640.       , 637.2583   ]],
#         dtype=float32),
#   'pred_labels': array([3, 2], dtype=int64),
#   'pred_scores': array([0.6831825, 0.6804655], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 65,
#   'pred_boxes': array([[0.0000000e+00, 6.3769531e-01, 6.3914679e+02, 6.3937311e+02],
#          [1.5467834e+00, 6.2796021e-01, 6.3882458e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.9210708 , 0.22428913], dtype=float32),
#   'true_boxes': array([[  0.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 66,
#   'pred_boxes': array([[1.7623901e-01, 1.2193909e+00, 6.3950085e+02, 6.3783362e+02],
#          [1.0586853e+00, 0.0000000e+00, 6.4000000e+02, 6.3771082e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.783567 , 0.4031065], dtype=float32),
#   'true_boxes': array([[  0.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 67,
#   'pred_boxes': array([[  1.3597107,   1.0003662, 638.63257  , 640.       ],
#          [  1.34729  ,   1.3581238, 639.86774  , 637.34534  ]],
#         dtype=float32),
#   'pred_labels': array([3, 2], dtype=int64),
#   'pred_scores': array([0.82687473, 0.5120967 ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 68,
#   'pred_boxes': array([[  0.      ,   1.251648, 640.      , 640.      ],
#          [  0.      ,   0.      , 639.87897 , 640.      ],
#          [  0.      ,   0.      , 640.      , 637.8508  ]], dtype=float32),
#   'pred_labels': array([1, 2, 3], dtype=int64),
#   'pred_scores': array([0.84604466, 0.7352517 , 0.11461757], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 69,
#   'pred_boxes': array([[4.9639893e-01, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [1.0897217e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.9219092 , 0.12083807], dtype=float32),
#   'true_boxes': array([[  4. ,   2. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 70,
#   'pred_boxes': array([[6.9973755e-01, 5.8352661e-01, 6.3928748e+02, 6.3898926e+02],
#          [1.9989929e+00, 0.0000000e+00, 6.3604614e+02, 6.4000000e+02],
#          [4.5770264e-01, 1.8676758e+00, 6.4000000e+02, 6.3678308e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.8248034 , 0.29987028, 0.288168  ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 71,
#   'pred_boxes': array([[3.9550781e-02, 1.8363953e+00, 6.4000000e+02, 6.3971533e+02],
#          [2.3842163e+00, 0.0000000e+00, 6.4000000e+02, 6.3820679e+02],
#          [1.1549683e+00, 3.6902466e+00, 6.4000000e+02, 6.3454071e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.9302708 , 0.11108614, 0.10281684], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 72,
#   'pred_boxes': array([[2.0378723e+00, 0.0000000e+00, 6.3935669e+02, 6.4000000e+02],
#          [6.3226318e-01, 8.0142212e-01, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.87227947, 0.42870405], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 73,
#   'pred_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9946062], dtype=float32),
#   'true_boxes': array([[  0.,   8., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 74,
#   'pred_boxes': array([[0.0000000e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [7.8765869e-02, 1.9755554e+00, 6.4000000e+02, 6.3973535e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.7683031, 0.5617216], dtype=float32),
#   'true_boxes': array([[  0.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 75,
#   'pred_boxes': array([[0.0000000e+00, 6.3793945e-01, 6.4000000e+02, 6.3820416e+02]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9973615], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 76,
#   'pred_boxes': array([[  0.       ,   4.934082 , 634.7909   , 638.6771   ],
#          [  1.7683411,   0.9863281, 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.9124966 , 0.18475664], dtype=float32),
#   'true_boxes': array([[  5.,   3., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 77,
#   'pred_boxes': array([[0.0000000e+00, 6.2612915e-01, 6.3619434e+02, 6.3951526e+02],
#          [1.3650208e+00, 1.8433228e+00, 6.3833008e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.8916598 , 0.41181955], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 78,
#   'pred_boxes': array([[  1.3400879,   2.2312317, 639.73694  , 637.74414  ]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.99591607], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 79,
#   'pred_boxes': array([[  0.    ,   0.    , 639.8729, 640.    ]], dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9917149], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 80,
#   'pred_boxes': array([[  0.       ,   0.       , 640.       , 640.       ],
#          [  1.1525269,   0.       , 640.       , 637.56226  ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.9185377 , 0.16828129], dtype=float32),
#   'true_boxes': array([[  0.,   3., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 81,
#   'pred_boxes': array([[  0.     ,   0.     , 639.34595, 640.     ]], dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.99943477], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 82,
#   'pred_boxes': array([[0.0000000e+00, 5.3839111e-01, 6.4000000e+02, 6.4000000e+02],
#          [3.0620422e+00, 0.0000000e+00, 6.3841980e+02, 6.4000000e+02],
#          [0.0000000e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.80776244, 0.28576764, 0.16303068], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 83,
#   'pred_boxes': array([[0.0000000e+00, 1.0971375e+00, 6.4000000e+02, 6.3774646e+02],
#          [1.8706055e+00, 9.5367432e-02, 6.3989728e+02, 6.3941492e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.8723594 , 0.42060637], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 84,
#   'pred_boxes': array([[  1.9868774 ,   1.1939697 , 639.6876    , 640.        ],
#          [  2.223755  ,   0.72784424, 640.        , 638.6285    ]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.7317131 , 0.49209708], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 85,
#   'pred_boxes': array([[3.8357544e-01, 4.1511230e+00, 6.3982532e+02, 6.4000000e+02],
#          [1.0296631e-01, 1.0497437e+00, 6.3949683e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2], dtype=int64),
#   'pred_scores': array([0.85859424, 0.7767782 ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 86,
#   'pred_boxes': array([[1.2366333e+00, 0.0000000e+00, 6.3897473e+02, 6.4000000e+02],
#          [0.0000000e+00, 2.4124146e-01, 6.3797723e+02, 6.3964368e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.9502828 , 0.12056462], dtype=float32),
#   'true_boxes': array([[  0.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 87,
#   'pred_boxes': array([[  0.    ,   0.    , 640.    , 639.7201],
#          [  0.    ,   0.    , 640.    , 640.    ]], dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.89084595, 0.3400885 ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 88,
#   'pred_boxes': array([[2.0904541e-01, 2.7698364e+00, 6.3883118e+02, 6.3904388e+02],
#          [5.8978271e-01, 3.2147217e-01, 6.4000000e+02, 6.3995398e+02],
#          [1.5172729e+00, 7.2143555e-02, 6.4000000e+02, 6.3846820e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3, 2], dtype=int64),
#   'pred_scores': array([0.7515517 , 0.6746779 , 0.07292629], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 89,
#   'pred_boxes': array([[  1.2807312,   3.4925537, 640.       , 639.6997   ],
#          [  5.5066833,   6.535553 , 639.844    , 639.6653   ]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.70494574, 0.65636647], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 90,
#   'pred_boxes': array([[  2.3778381,   0.       , 634.8583   , 640.       ],
#          [  0.       ,   0.       , 640.       , 638.9893   ]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.8918898, 0.5234367], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 91,
#   'pred_boxes': array([[  1.5163574,   0.       , 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.99883467], dtype=float32),
#   'true_boxes': array([[  0.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 92,
#   'pred_boxes': array([[  0.66693115,   4.6707153 , 640.        , 637.5525    ],
#          [  2.1999512 ,   1.6010132 , 636.19147   , 640.        ]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.9894723 , 0.15495919], dtype=float32),
#   'true_boxes': array([[  1.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 93,
#   'pred_boxes': array([[  1.0658569,   1.3046875, 638.29706  , 639.6193   ],
#          [  4.222473 ,   1.4785767, 639.33386  , 639.2196   ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.81150365, 0.35383296], dtype=float32),
#   'true_boxes': array([[  1.,   1., 640., 639.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 94,
#   'pred_boxes': array([[2.1481934e+00, 3.8293457e-01, 6.3898102e+02, 6.3982013e+02]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9940602], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 95,
#   'pred_boxes': array([[0.0000000e+00, 2.9373169e-01, 6.3568213e+02, 6.3974756e+02],
#          [0.0000000e+00, 0.0000000e+00, 6.4000000e+02, 6.3867126e+02],
#          [3.0812378e+00, 3.0610046e+00, 6.3898212e+02, 6.3788306e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 4, 2], dtype=int64),
#   'pred_scores': array([0.88545245, 0.42026094, 0.28684267], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 96,
#   'pred_boxes': array([[  1.4937134,   0.       , 640.       , 639.31006  ],
#          [  0.       ,   0.       , 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.94393915, 0.08671943], dtype=float32),
#   'true_boxes': array([[  2.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 97,
#   'pred_boxes': array([[  0.       ,   3.5377808, 640.       , 638.6279   ],
#          [  0.       ,   1.5632629, 640.       , 637.8688   ]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.9489395 , 0.26714453], dtype=float32),
#   'true_boxes': array([[  1. ,   0. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 98,
#   'pred_boxes': array([[  0.        ,   1.7177124 , 640.        , 639.4087    ],
#          [  2.6627197 ,   0.73898315, 639.2241    , 635.93005   ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.9515532, 0.2434793], dtype=float32),
#   'true_boxes': array([[  2.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 99,
#   'pred_boxes': array([[  2.6489868,   1.6344604, 638.63495  , 639.5463   ],
#          [  1.4714355,   2.7503967, 640.       , 637.2477   ],
#          [  4.4526978,   2.5925293, 638.57526  , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.8809934 , 0.2500765 , 0.19702615], dtype=float32),
#   'true_boxes': array([[  3.,   3., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 100,
#   'pred_boxes': array([[5.3637695e-01, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [0.0000000e+00, 0.0000000e+00, 6.3948395e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.9264311, 0.3059028], dtype=float32),
#   'true_boxes': array([[  1.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 101,
#   'pred_boxes': array([[  2.690216 ,   0.6462097, 640.       , 639.5668   ],
#          [  0.       ,   1.0621948, 640.       , 640.       ],
#          [  0.       ,   0.       , 636.2533   , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.6935202 , 0.54878557, 0.07451169], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 102,
#   'pred_boxes': array([[  0.7337036,   0.       , 639.9222   , 640.       ],
#          [  3.4174194,   2.9584045, 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([3, 2], dtype=int64),
#   'pred_scores': array([0.725232 , 0.6185524], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 103,
#   'pred_boxes': array([[3.1213379e-01, 2.6779175e-01, 6.3939557e+02, 6.4000000e+02],
#          [2.5790405e-01, 4.0066833e+00, 6.3480640e+02, 6.3958496e+02],
#          [1.1968079e+00, 4.8587036e-01, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3, 1], dtype=int64),
#   'pred_scores': array([0.7637434 , 0.27576476, 0.219871  ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 104,
#   'pred_boxes': array([[  1.2496643,   1.6104736, 640.       , 640.       ],
#          [  1.0875244,   2.4397888, 640.       , 636.7682   ],
#          [  0.       ,   1.3135376, 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.7277401 , 0.49278268, 0.06922464], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 105,
#   'pred_boxes': array([[1.2507324e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [1.0121460e+00, 4.4384766e-01, 6.3977155e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.8242378, 0.5698901], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 106,
#   'pred_boxes': array([[5.4656982e-01, 1.1454163e+00, 6.4000000e+02, 6.4000000e+02],
#          [0.0000000e+00, 7.9439392e+00, 6.4000000e+02, 6.3725818e+02]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.97412884, 0.26067445], dtype=float32),
#   'true_boxes': array([[  5.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 107,
#   'pred_boxes': array([[  0.       ,   1.3110046, 640.       , 640.       ],
#          [  0.       ,   2.0448914, 640.       , 640.       ],
#          [  0.       ,   0.       , 640.       , 639.8805   ]],
#         dtype=float32),
#   'pred_labels': array([3, 4, 2], dtype=int64),
#   'pred_scores': array([0.8163269 , 0.4691942 , 0.13112289], dtype=float32),
#   'true_boxes': array([[  4. ,   0. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 108,
#   'pred_boxes': array([[0.0000000e+00, 1.4928284e+00, 6.3828601e+02, 6.4000000e+02],
#          [9.9148560e-01, 2.4624634e+00, 6.4000000e+02, 6.4000000e+02],
#          [0.0000000e+00, 1.6757202e-01, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.8825488 , 0.23833467, 0.08156628], dtype=float32),
#   'true_boxes': array([[  0.,  10., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 109,
#   'pred_boxes': array([[2.3861694e-01, 3.9207153e+00, 6.4000000e+02, 6.3916559e+02],
#          [4.8919678e-01, 1.2612305e+00, 6.3839978e+02, 6.3971570e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.8271437 , 0.38239077], dtype=float32),
#   'true_boxes': array([[  4. ,   0. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 110,
#   'pred_boxes': array([[  4.135254 ,   1.0694275, 639.88684  , 640.       ],
#          [  0.       ,   1.4723816, 640.       , 637.02966  ]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.9949366 , 0.09274179], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 111,
#   'pred_boxes': array([[  1.3354187,   0.9082947, 640.       , 639.7428   ],
#          [  0.       ,   1.494873 , 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([3, 4], dtype=int64),
#   'pred_scores': array([0.9039502 , 0.39593458], dtype=float32),
#   'true_boxes': array([[  3.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 112,
#   'pred_boxes': array([[  0.        ,   0.98846436, 639.70703   , 640.        ]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9994018], dtype=float32),
#   'true_boxes': array([[  0.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 113,
# ...
#   'true_boxes': array([[  0. ,   2. , 640. , 639.5]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 170,
#   'pred_boxes': array([[0.0000000e+00, 6.1865234e-01, 6.4000000e+02, 6.4000000e+02],
#          [4.9087524e-01, 0.0000000e+00, 6.3979810e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.7720644 , 0.45909882], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 171,
#   'pred_boxes': array([[  0.       ,   3.9305725, 640.       , 639.04456  ],
#          [  0.6586304,   0.       , 639.7999   , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([3, 4], dtype=int64),
#   'pred_scores': array([0.89909214, 0.48823568], dtype=float32),
#   'true_boxes': array([[  0.,   2., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 172,
#   'pred_boxes': array([[0.0000000e+00, 1.9970093e+00, 6.4000000e+02, 6.3964215e+02],
#          [2.0921326e+00, 1.7359314e+00, 6.4000000e+02, 6.3944690e+02],
#          [7.8878784e-01, 5.7269287e-01, 6.4000000e+02, 6.3896417e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.894327  , 0.16011296, 0.06171693], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 173,
#   'pred_boxes': array([[2.8381348e-03, 1.2684021e+00, 6.4000000e+02, 6.3795483e+02],
#          [1.8463745e+00, 0.0000000e+00, 6.3976843e+02, 6.4000000e+02],
#          [2.0287476e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.82357764, 0.3369419 , 0.10907111], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 174,
#   'pred_boxes': array([[  2.4387207,   0.       , 640.       , 640.       ],
#          [  1.8794556,   2.4811401, 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.87700254, 0.5485673 ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 175,
#   'pred_boxes': array([[1.6262817e-01, 1.4658813e+00, 6.4000000e+02, 6.3930219e+02],
#          [2.1466370e+00, 2.5325317e+00, 6.3846423e+02, 6.3979541e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.73621416, 0.47113132], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 176,
#   'pred_boxes': array([[1.7771912e+00, 2.6824951e-02, 6.3702515e+02, 6.3910059e+02],
#          [3.1326294e-01, 3.3580017e+00, 6.3978455e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.90987116, 0.62919927], dtype=float32),
#   'true_boxes': array([[  2. ,   4. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 177,
#   'pred_boxes': array([[  0.       ,   0.       , 640.       , 640.       ],
#          [  0.8294983,   0.       , 639.1221   , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.8755692 , 0.37286243], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 178,
#   'pred_boxes': array([[  2.0307312,   0.815979 , 639.8092   , 639.7665   ],
#          [  1.5912476,   0.       , 638.8697   , 639.3965   ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.753153  , 0.57931644], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 179,
#   'pred_boxes': array([[  1.6901245,   1.8830566, 640.       , 640.       ],
#          [  2.3901978,   0.       , 636.3145   , 638.49133  ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.95070994, 0.13980559], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 180,
#   'pred_boxes': array([[1.4932251e-01, 0.0000000e+00, 6.3998352e+02, 6.4000000e+02],
#          [2.0739746e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3], dtype=int64),
#   'pred_scores': array([0.95397127, 0.1991385 ], dtype=float32),
#   'true_boxes': array([[  0.,   6., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 181,
#   'pred_boxes': array([[2.6327515e-01, 8.8378906e-02, 6.3836646e+02, 6.4000000e+02],
#          [2.0254822e+00, 0.0000000e+00, 6.3901770e+02, 6.4000000e+02],
#          [3.9630127e+00, 1.6650696e+00, 6.3963330e+02, 6.3971460e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.84448355, 0.27410504, 0.1444216 ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 182,
#   'pred_boxes': array([[  2.3010254,   0.828125 , 639.4955   , 640.       ],
#          [  1.4103088,   1.7492676, 639.4103   , 638.5058   ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.76795316, 0.45569426], dtype=float32),
#   'true_boxes': array([[  1. ,   0. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 183,
#   'pred_boxes': array([[  1.6290283,   0.       , 639.17255  , 639.8749   ],
#          [  2.1934814,   0.       , 632.896    , 639.92676  ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.9533783 , 0.11809279], dtype=float32),
#   'true_boxes': array([[  0.,   2., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 184,
#   'pred_boxes': array([[1.6407166e+00, 0.0000000e+00, 6.3836243e+02, 6.4000000e+02],
#          [0.0000000e+00, 0.0000000e+00, 6.3954346e+02, 6.4000000e+02],
#          [4.4018555e-01, 0.0000000e+00, 6.3856036e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.93241566, 0.24806823, 0.06397919], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 185,
#   'pred_boxes': array([[  0.       ,   2.7184143, 640.       , 639.12854  ],
#          [  1.8547974,   0.7202759, 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.94153595, 0.27475354], dtype=float32),
#   'true_boxes': array([[  0.,   1., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 186,
#   'pred_boxes': array([[  2.4294739,   1.7622681, 639.38855  , 638.2479   ],
#          [  0.       ,   1.1766052, 640.       , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([3, 4], dtype=int64),
#   'pred_scores': array([0.72054577, 0.66264665], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 187,
#   'pred_boxes': array([[1.8334961e+00, 0.0000000e+00, 6.4000000e+02, 6.3864502e+02],
#          [2.9083252e-02, 2.7323608e+00, 6.3836951e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2], dtype=int64),
#   'pred_scores': array([0.9090586, 0.73118  ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 188,
#   'pred_boxes': array([[1.4468994e+00, 6.1230469e-01, 6.3817004e+02, 6.3834949e+02],
#          [0.0000000e+00, 1.1277466e+00, 6.4000000e+02, 6.3693408e+02]],
#         dtype=float32),
#   'pred_labels': array([1, 2], dtype=int64),
#   'pred_scores': array([0.94828993, 0.39478838], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 189,
#   'pred_boxes': array([[0.0000000e+00, 7.9678345e-01, 6.4000000e+02, 6.4000000e+02],
#          [7.7664185e-01, 9.4763184e-01, 6.4000000e+02, 6.3904651e+02],
#          [3.9904785e-01, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3, 1], dtype=int64),
#   'pred_scores': array([0.7681507 , 0.52849567, 0.09383465], dtype=float32),
#   'true_boxes': array([[  9. ,  17. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 190,
#   'pred_boxes': array([[2.8866577e-01, 2.2207642e+00, 6.3944092e+02, 6.3883844e+02],
#          [1.1580811e+00, 0.0000000e+00, 6.3867120e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.931833  , 0.13994859], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 191,
#   'pred_boxes': array([[1.6555176e+00, 1.0390320e+00, 6.3951770e+02, 6.3923694e+02],
#          [1.5683289e+00, 8.3163452e-01, 6.3980298e+02, 6.3925366e+02],
#          [1.1402283e+00, 5.3976440e-01, 6.4000000e+02, 6.3965161e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.8281409 , 0.58045155, 0.13110557], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 192,
#   'pred_boxes': array([[2.8723145e-01, 4.8416138e+00, 6.4000000e+02, 6.4000000e+02],
#          [2.0598877e+01, 2.6085388e+01, 6.3128815e+02, 6.3396313e+02],
#          [2.5667572e+01, 3.2308105e+01, 6.2683606e+02, 6.3589801e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 3, 1], dtype=int64),
#   'pred_scores': array([0.9551265 , 0.10530947, 0.06971277], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 193,
#   'pred_boxes': array([[  0.       ,   1.3822021, 640.       , 639.42645  ],
#          [  1.0119934,   0.       , 638.30676  , 638.92065  ]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.85625213, 0.3683525 ], dtype=float32),
#   'true_boxes': array([[  1.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([4], dtype=int64)},
#  {'image_id': 194,
#   'pred_boxes': array([[0.0000000e+00, 4.4442749e-01, 6.3995258e+02, 6.3851306e+02],
#          [1.8556213e+00, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [2.7794495e+00, 0.0000000e+00, 6.3867310e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 1, 3], dtype=int64),
#   'pred_scores': array([0.82295895, 0.58508617, 0.06564613], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([1], dtype=int64)},
#  {'image_id': 195,
#   'pred_boxes': array([[  1.4320374,   3.8278809, 639.6836   , 639.30585  ],
#          [  0.7559204,   0.       , 639.25543  , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([2, 1], dtype=int64),
#   'pred_scores': array([0.75162   , 0.55447876], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 196,
#   'pred_boxes': array([[2.8762817e-01, 3.2232666e-01, 6.3799011e+02, 6.4000000e+02],
#          [0.0000000e+00, 1.9658203e+00, 6.3761383e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.67963475, 0.5316545 ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 197,
#   'pred_boxes': array([[3.1265259e-01, 0.0000000e+00, 6.4000000e+02, 6.4000000e+02],
#          [1.5765076e+00, 0.0000000e+00, 6.4000000e+02, 6.3770935e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 4], dtype=int64),
#   'pred_scores': array([0.81921285, 0.40108776], dtype=float32),
#   'true_boxes': array([[  2.,   2., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 198,
#   'pred_boxes': array([[1.3747864e+00, 5.4541016e-01, 6.3826257e+02, 6.3931433e+02],
#          [0.0000000e+00, 1.6019897e+00, 6.4000000e+02, 6.3869928e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 4], dtype=int64),
#   'pred_scores': array([0.718373 , 0.5397255], dtype=float32),
#   'true_boxes': array([[  0.,   3., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 199,
#   'pred_boxes': array([[0.0000000e+00, 0.0000000e+00, 6.3850513e+02, 6.3923560e+02],
#          [2.9518127e+00, 3.1997681e-01, 6.3980200e+02, 6.3893262e+02]],
#         dtype=float32),
#   'pred_labels': array([2, 1], dtype=int64),
#   'pred_scores': array([0.9758614 , 0.16449226], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 200,
#   'pred_boxes': array([[  1.4184265,   5.5532837, 640.       , 639.48004  ],
#          [  0.       ,   0.9844971, 639.6831   , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([3, 2], dtype=int64),
#   'pred_scores': array([0.75861895, 0.5244537 ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 201,
#   'pred_boxes': array([[0.0000000e+00, 8.0419922e-01, 6.3870056e+02, 6.3997430e+02],
#          [0.0000000e+00, 0.0000000e+00, 6.3797491e+02, 6.4000000e+02],
#          [7.8369141e-02, 5.6030273e-02, 6.4000000e+02, 6.4000000e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.75105304, 0.4562072 , 0.4062095 ], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([2], dtype=int64)},
#  {'image_id': 202,
#   'pred_boxes': array([[2.0214233e+00, 1.8874207e+00, 6.4000000e+02, 6.3826318e+02],
#          [1.3828735e+00, 6.3494873e-01, 6.4000000e+02, 6.3947668e+02],
#          [1.2775879e+00, 2.0603333e+00, 6.4000000e+02, 6.3937744e+02]],
#         dtype=float32),
#   'pred_labels': array([3, 2, 4], dtype=int64),
#   'pred_scores': array([0.8981612 , 0.14625855, 0.09680331], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 203,
#   'pred_boxes': array([[  2.2759705 ,   2.006012  , 638.6538    , 638.47754   ],
#          [  2.8309937 ,   0.76312256, 638.4448    , 640.        ],
#          [  3.3507996 ,   1.6922607 , 638.95654   , 640.        ],
#          [  1.0796204 ,   1.1356506 , 637.8772    , 640.        ]],
#         dtype=float32),
#   'pred_labels': array([2, 3, 1, 4], dtype=int64),
#   'pred_scores': array([0.82884234, 0.73919016, 0.06094153, 0.05520706], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 204,
#   'pred_boxes': array([[1.7820740e+00, 6.8536377e-01, 6.4000000e+02, 6.4000000e+02],
#          [1.8558960e+00, 4.7717285e-01, 6.3996405e+02, 6.3731476e+02]],
#         dtype=float32),
#   'pred_labels': array([4, 3], dtype=int64),
#   'pred_scores': array([0.91085744, 0.20961076], dtype=float32),
#   'true_boxes': array([[  0.,   0., 640., 640.]], dtype=float32),
#   'true_labels': array([3], dtype=int64)},
#  {'image_id': 205,
#   'pred_boxes': array([[  0.       ,   2.2174683, 639.1179   , 640.       ]],
#         dtype=float32),
#   'pred_labels': array([1], dtype=int64),
#   'pred_scores': array([0.9981219], dtype=float32),
#   'true_boxes': array([[  2. ,   0. , 639.5, 640. ]], dtype=float32),
#   'true_labels': array([1], dtype=int64)}]

# %%
import torch
from torchvision.transforms import functional as F
import torchvision.transforms as T
from PIL import Image, ImageOps
import io

def test_model(model, image, device=None):
    model.to(device)
    model.eval()  # Set the model to evaluation mode
    
    with torch.no_grad():
        # Move image to the device
        image = [image.to(device)]
        
        # Get predictions from the model
        outputs = model(image)
        
        # Process outputs
        for output in outputs:
            pred_boxes = output['boxes'].cpu().numpy()
            pred_labels = output['labels'].cpu().numpy()
            pred_scores = output['scores'].cpu().numpy()
            
            # Store predictions and ground truth
            predictions = {
                "pred_boxes": pred_boxes,
                "pred_labels": pred_labels,
                "pred_scores": pred_scores,
            }

    return predictions

def get_transform(image):
    transform = T.Compose([
        T.ToTensor(),
        T.Resize((640, 640)),  # Stretch to 640x640
        T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Standard normalization
    ])
    return transform(image)

def auto_orient(image):
    # Auto-orient the image based on EXIF data
    try:
        image = Image.open(image)
        image = ImageOps.exif_transpose(image)
    except Exception as e:
        print(f"Error in auto-orienting image: {e}")
    return image

path = "dataset/pressureV1/test/20019_jpg.rf.73b61f3a6e7da15ed828604408a1b8eb.jpg"
img = auto_orient(path)
img = get_transform(img)
# print(img)
pred = test_model(model, img, "cpu")
pred
# Out:
# {'pred_boxes': array([[2.1481934e+00, 3.8293457e-01, 6.3898096e+02, 6.3982013e+02]],
#        dtype=float32),
#  'pred_labels': array([1], dtype=int64),
#  'pred_scores': array([0.99406034], dtype=float32)}
